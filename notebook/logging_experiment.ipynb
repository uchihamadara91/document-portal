# %%
print("all ok")
# Out:
# all ok

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(),"logs")

# %%
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%d-%m-%Y_%H-%M-%S')}.log"

# %%
LOG_FILE
# Out:
# '27-07-2025_20-09-15.log'

# %%
LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
logger = logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %%
import structlog

log = structlog.get_logger()

# %%
log.info("User uploaded a file", user_id=123, filename="report.pdf" )
# Out:
# 2025-07-27 20:17:05 [info     ] User uploaded a file           filename=report.pdf user_id=123

# %%
log.error("Failed to process PDF", error="File not found", user_id=123)
# Out:
# 2025-07-27 20:18:12 [error    ] Failed to process PDF          error='File not found' user_id=123

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"MyClass Object with name: {self.name}"
    
    def __repr__(self):
        return f"MyClass Object with name: {self.name}"

# %%
obj = MyClass("Shankar")

# %%
print(obj)
# Out:
# MyClass Object with name: Shankar

# %%
repr(obj)
# Out:
# 'MyClass Object with name: Shankar'
